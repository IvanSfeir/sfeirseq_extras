# %%
import pandas as pd

# %%
results = pd.read_csv("/run/user/71447/gvfs/sftp:host=decore0.imag.fr,user=sfeirj/home/getalp/sfeirj/results/waves/results_wave_2")
results = results.drop(["syslen", "reflen", "score3", "score4", "my_mean", "my_sqrt", "my_diff_count"], axis=1)
results.head()
# Out:
#        lr  nb_layers  embed_dim  dropout  epoch       BLEU     score1  \
# 0  0.0005          2         32     0.05     10  75.595702  83.334517
# 1  0.0005          2         32     0.10     15  75.453576  83.248557
# 2  0.0005          2         64     0.05      8  77.257204  84.313003
# 3  0.0005          2         64     0.10     10  78.078855  85.158753
# 4  0.0005          2        128     0.05      8  64.714533  71.743330
#
#       score2   brevity     ratio
# 0  78.173636  0.996692  0.996698
# 1  77.871952  0.999328  0.999328
# 2  79.495931  1.000000  1.007931
# 3  80.582677  0.995668  0.995678
# 4  67.020982  1.000000  1.184302

# %%
results.sort_values(by=['score1'], ascending=False)
# Out:
#         lr  nb_layers  embed_dim  dropout  epoch       BLEU     score1  \
# 3   0.0005          2         64     0.10     10  78.078855  85.158753
# 2   0.0005          2         64     0.05      8  77.257204  84.313003
# 0   0.0005          2         32     0.05     10  75.595702  83.334517
# 1   0.0005          2         32     0.10     15  75.453576  83.248557
# 5   0.0005          2        128     0.10      9  73.870825  81.572233
# 10  0.0005          3        128     0.05     10  73.882612  81.296292
# 12  0.0005          4         32     0.05     13  72.917440  81.086130
# 6   0.0005          3         32     0.05     14  72.497085  80.911400
# 15  0.0005          4         64     0.10      5  65.457811  80.752783
# 9   0.0005          3         64     0.10     15  73.031739  80.585965
# 16  0.0005          4        128     0.05      6  64.168416  80.238039
# 13  0.0005          4         32     0.10     19  71.305885  80.159076
# ...
